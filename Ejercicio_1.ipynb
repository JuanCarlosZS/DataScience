# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanCarlosZS/DataScience/blob/main/Ejercicio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ejercicio practico de Clase 1 - Primer grafico con matplotlib
# ✈[Esta es la presentacion](https://docs.google.com/presentation/d/1OhwYkGXfY9xDGjP7cRscmms6Cd4ogESgaRvRY17fY-I/edit?slide=id.g22048273d13_2_207#slide=id.g22048273d13_2_207)

# %%
import pandas

# %%
x:list[str] = ['EDA','Data Wrangling','Mineria datos','Limpieza Datos','SQL','Est. Inferencial','ML','DL','IA']
y:list[int ]= [5,10,15,20,30,25,31,30,20]

# %%
data_dict:dict = {
    "Caracteristicas": x,
     "Frecuencia": y
}

data_dict
# Out:
# {'Caracteristicas': ['EDA',
#   'Data Wrangling',
#   'Mineria datos',
#   'Limpieza Datos',
#   'SQL',
#   'Est. Inferencial',
#   'ML',
#   'DL',
#   'IA'],
#  'Frecuencia': [5, 10, 15, 20, 30, 25, 31, 30, 20]}

# %%
x:list[str] = ['EDA','Data Wrangling','Mineria datos','Limpieza Datos','SQL','Est. Inferencial','ML','DL','IA']
y:list[int ]= [5,10,15,20,30,25,31,30,20]

data_dict:dict = {
    "Caracteristicas": x,
     "Frecuencia": y
}

df = pandas.DataFrame(data_dict)

# %%
df
# Out:
#     Caracteristicas  Frecuencia
# 0               EDA           5
# 1    Data Wrangling          10
# 2     Mineria datos          15
# 3    Limpieza Datos          20
# 4               SQL          30
# 5  Est. Inferencial          25
# 6                ML          31
# 7                DL          30
# 8                IA          20

# %%
plt.figure(figsize=(16,9))
sns.barplot(df, x="Caracteristicas", y="Frecuencia")
plt.show()
